# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("titanic_data.csv")

# %%
df.shape
# Out:
# (418, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df['Cabin']=df['Cabin'].fillna(df['Cabin'].mode()[0])
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df['Fare']=df['Fare'].fillna(df['Fare'].mean())
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
cab=df["Cabin"].tolist()
print(cab)
# Out:
# ['B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B45', 'B57 B59 B63 B66', 'E31', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B36', 'B57 B59 B63 B66', 'A21', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'C78', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'D34', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'D19', 'B57 B59 B63 B66', 'A9', 'B57 B59 B63 B66', 'D15', 'B57 B59 B63 B66', 'C31', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'C23 C25 C27', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'B57 B59 B63 B66', 'F G63', 'B57 B59 B63 B66', 'B61', 'B57
# ...

# %%
single_list=[item for element in cab for item in element.split()]
print(single_list)
# Out:
# ['B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B45', 'B57', 'B59', 'B63', 'B66', 'E31', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B36', 'B57', 'B59', 'B63', 'B66', 'A21', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'C78', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B59', 'B63', 'B66', 'B57', 'B5
# ...

# %%
df['Cabin']=np.random.choice(single_list, size=len(df))
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Age']=df['Age'].astype(int)
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex  Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male   34      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                     Myles, Mr. Thomas Francis    male   62      0      0
# 3                              Wirz, Mr. Albert    male   27      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   B69        Q
# 1   363272   7.0000    A9        S
# 2   240276   9.6875   B66        Q
# 3   315154   8.6625   B57        S
# 4  3101298  12.2875   B63        S

# %%
df["Cabin"].max()
# Out:
# 'F4'

# %%
#Print first 4 columns 
df.iloc[:, 0:4]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..                                            ...
# 413                            Spector, Mr. Woolf
# 414                  Oliva y Ocana, Dona. Fermina
# 415                  Saether, Mr. Simon Sivertsen
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    int64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Cabin        418 non-null    object
#  11  Embarked     418 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 39.3+ KB

# %%
#Print no of survivers
df[df["Survived"].isin([1])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female   47      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1
# 6                               Connolly, Miss. Kate  female   30      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female   18      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female   23      1
# ..                                               ...     ...  ...    ...
# ...

# %%
#male
df1=df[df["Sex"].isin(["male"])]
df1
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 0            892         0       3              Kelly, Mr. James  male   34
# 2            894         0       2     Myles, Mr. Thomas Francis  male   62
# 3            895         0       3              Wirz, Mr. Albert  male   27
# 5            897         0       3    Svensson, Mr. Johan Cervin  male   14
# 7            899         0       2  Caldwell, Mr. Albert Francis  male   26
# ..           ...       ...     ...                           ...   ...  ...
# 407         1299         0       1    Widener, Mr. George Dunton  male   50
# 413         1305         0       3            Spector, Mr. Woolf  male   30
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male   38
# 416         1308         0       3           Ware, Mr. Frederick  male   30
# 417         1309         0       3      Peter, Master. Michael J  male   30
#
# ...

# %%
#female
df2=df[df["Sex"].isin(["female"])]
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female   47      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1
# 6                               Connolly, Miss. Kate  female   30      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female   18      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female   23      1
# ..                                               ...     ...  ...    ...
# ...

# %%
#age
df[(df["Age"]>20)&(df["Age"]<35)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 3            895         0       3
# 4            896         1       3
# 6            898         1       3
# 7            899         0       2
# ..           ...       ...     ...
# 410         1302         1       3
# 412         1304         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# 6                            Connolly, Miss. Kate  female   30      0      0
# 7                    Caldwell, Mr. Albert Francis    male   26      1      1
# ...
